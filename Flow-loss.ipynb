# %%
# %%bash
# cd /content/Robust-MSCN
# git add .
# git commit -m "Update notebook"
# git push origin eric
# Out:
# [eric d90baea] Update notebook
#  4 files changed, 8 insertions(+), 5 deletions(-)
#  rewrite Robust-MSCN.ipynb (65%)
# To github.com:Erostrate9/Robust-MSCN.git
#    5e60cd9..d90baea  eric -> eric

# %% [markdown]
# # Install Enviroment

# %% [markdown]
# ## Download workload queries (dataset)
# Note: there're some typos in downloading scripts. They didn't download the imdb_data.json correctly. We have to correct download_imdb_workload.sh, download_job_workload.sh and download_imdb_updates.sh:
# ```bash
# ## downloading data about imdb schema etc.
# wget -O imdb_data.json https://www.dropbox.com/s/nxtt17s4gdt21r5/imdb_data.json?dl=1
# cp imdb_data.json queries/ceb-imdb-full/dbdata.json
#
# ```

# %%
# %%bash
# # download IMDB workload
# cd Robust-MSCN
# bash scripts/download_imdb_workload.sh

# %% [markdown]
# ## PostgreSQL Configuration

# %% [markdown]
# - We use docker to install and configure PostgreSQL, and setup the relevant databases.
#
# - Make sure that you have Docker installed appropriately for your system, with the docker daemon running.
# - PostgreSQL requires a username, which we copy from an environement variable \$LCARD_USER while setting it up in docker. Similarly, set \$LCARD_PORT to the local port you want to use to connect to the PostgreSQL instance running in docker. Here are the commands to set it up:

# %% [markdown]
# - You cannot run docker daemon on Colab (at least not on the free version). Therefore, I recommend running docker locall
#
# - You can run the following bash on your local environment (e.g., Mac) to build the docker image
# ```bash
# cd docker
# export LCARD_USER=imdb
# export LCARD_PORT=5432
# docker build --build-arg LCARD_USER=imdb -t pg12 .
# docker save -o pg12.tar pg12
# docker run -itd --shm-size=1g --name card-db -p 5432:5432 -d pg12
# docker restart card-db
# docker exec -it card-db /imdb_setup.sh
# ```
# - Alternatively, you can use image that I uploaded:
# ```bash
# docker pull erostrate9/pg12:latest
# ```
#
#
# - To build Docker image on Mac, you need to add the clang dependency in Dockfile.
#
# ```
# RUN apt-get update && apt-get install -y \
#     clang \
#     wget \
#     tar \
#     git \
#     gcc \
#     build-essential \
#     postgresql-server-dev-12
# ```

# %% [markdown]
# ```
# # if your instance gets restarted / docker image gets shutdown
# sudo docker restart card-db
#
# # get a bash shell within the docker image
# sudo docker exec -it card-db bash
# # note that postgresql data on docker is stored at /var/lib/postgresql/data
#
# # If you failed to run `docker exec -it card-db /imdb_setup.sh`
# /imdb_setup.sh
#
#
#
# # connect psql on your host to the postgresql server running on docker
# psql -d imdb -h localhost -U ceb
# ```

# %% [markdown]
# ## Evaluating estimates
# Given a query, and estimates for each of its subplans, we can use various error functions to evaluate how good the estimates are. We can directly compare the true values and the estimated values, using for instance:
#
# Q-Error, Relative Error, Absolute Error etc. Q-Error is generally considered to be the most useful of these metrics from the perspective of query-optimization.
# Alternatively, we can compare how good was the plan generated by using the estimated values. This will depend on the query optimizer - in particular the properties of the cost model we choose, and the search function etc. We provide implementations for the two options as discussed in the paper, but by changing configurations of the PostgreSQL cost model, or adding more complex custom cost models, there can be many possibilities considered here.
#
# Postgres Plan Cost (PPC): this uses the PostgreSQL cost model with two restrictions --- no materialization and parallelism. For experimenting with different configurations, check the function set_cost_model in losses/plan_loss.py and add additional configurations.
#
# Plan-Cost: this considers only left deep plans, and uses a simple user specified cost function (referred to as C in the paper).
#
# Here is a self contained example showing the API to compute these different kind of errors on a single query.

# %%
from os.path import dirname, join, realpath
import sys
sys.path.append('/content/Robust-MSCN')
import os
os.chdir('/content/Robust-MSCN')
import query_representation
from query_representation.query import *
from evaluation.eval_fns import *
from psycopg2 import OperationalError

qfn = join(dirname(realpath(query_representation.__path__._path[0])), "queries/joblight_train/joblight-train-all/0.pkl")
qrep = load_qrep(qfn)
ests = get_postgres_cardinalities(qrep)

# estimation errors for each subplan in the query
qerr_fn = get_eval_fn("qerr")
abs_fn = get_eval_fn("abs")
rel_fn = get_eval_fn("rel")

qerr = qerr_fn.eval([qrep], [ests], result_dir=None)
abs_err = abs_fn.eval([qrep], [ests], result_dir=None)
relerr = rel_fn.eval([qrep], [ests],result_dir=None)

print("avg q-error: {}, avg abs-error: {}, avg relative error: {}".format(
              np.round(np.mean(qerr),2), np.round(np.mean(abs_err), 2),
                            np.round(np.mean(relerr), 2)))

# check the function comments to see the description of the arguments
# can change the db arguments appropriately depending on the PostgreSQL
# installation.
ppc = get_eval_fn("ppc")
port = 5432
# try:
ppc = ppc.eval([qrep], [ests], user="imdb", pwd="password", db_name="imdb",
        db_host="localhost", port=port, num_processes=-1, result_dir=None,
        cost_model="cm1")
# except OperationalError:
#     print(f"PGSQL not running at port {port}")
#     pass

# we considered only one query, so the returned lists have just one element
print("PPC is: {}".format(np.round(ppc[0])))

pc = get_eval_fn("plancost")
plan_cost = pc.eval([qrep], [ests], cost_model="C")
print("Plan-Cost is: {}".format(np.round(plan_cost[0])))
# Out:
# avg q-error: 2.13, avg abs-error: 901816.17, avg relative error: 0.5
# PPC is: 867303.0
# , #samples: 1, Relative Plan Cost: 1.0
# Plan-Cost is: 987052.0

# %% [markdown]
# ### True cardinality

# %%
from os.path import dirname, join, realpath
import query_representation
from query_representation.query import *
from evaluation.eval_fns import *
from psycopg2 import OperationalError

qfn = join(dirname(realpath(query_representation.__path__._path[0])), "queries/joblight_train/joblight-train-all/0.pkl")
qrep = load_qrep(qfn)
ests = get_true_cardinalities(qrep)

# estimation errors for each subplan in the query
qerr_fn = get_eval_fn("qerr")
abs_fn = get_eval_fn("abs")
rel_fn = get_eval_fn("rel")

qerr = qerr_fn.eval([qrep], [ests], result_dir=None)
abs_err = abs_fn.eval([qrep], [ests], result_dir=None)
relerr = rel_fn.eval([qrep], [ests],result_dir=None)

print("avg q-error: {}, avg abs-error: {}, avg relative error: {}".format(
              np.round(np.mean(qerr),2), np.round(np.mean(abs_err), 2),
                            np.round(np.mean(relerr), 2)))

# check the function comments to see the description of the arguments
# can change the db arguments appropriately depending on the PostgreSQL
# installation.
ppc = get_eval_fn("ppc")
port = 5432
# try:
ppc = ppc.eval([qrep], [ests], user="imdb", pwd="password", db_name="imdb",
        db_host="localhost", port=port, num_processes=-1, result_dir=None,
        cost_model="cm1")
# except OperationalError:
#     print(f"PGSQL not running at port {port}")
#     pass

# we considered only one query, so the returned lists have just one element
print("PPC is: {}".format(np.round(ppc[0])))

pc = get_eval_fn("plancost")
plan_cost = pc.eval([qrep], [ests], cost_model="C")
print("Plan-Cost is: {}".format(np.round(plan_cost[0])))
# Out:
# avg q-error: 1.0, avg abs-error: 0.0, avg relative error: 0.0
# PPC is: 510222.0
# , #samples: 1, Relative Plan Cost: 1.0
# Plan-Cost is: 987052.0

# %% [markdown]
# ## Getting runtimes
# - There are two steps to generating the runtimes; - first, we generate the Postgres Plan Cost, and the corresponding SQLs to execute.
# - These SQL strings would be annotated with various pg_hint_plan hints to enforce join order, operator selection and index Postgres Plan Costselection (see losses/plan_losses.py for details). These strings can be executed on PostgreSQL with pg_hint_plan loaded, but you may want to use a different setup for execution --- so other processes on the computer do not interfere with the execution times, and do things like clear the cache after every execution (cold start), or repeat each execution a few times etc. depending on your goals.
# - Here, we provide a simple example to execute the SQLs, but note that this does not clear caches, or take care about isolating the execution from other processes, so these timings won't be reliable.
# ```python
# # writes out the file results/Postgres/PostgresPlanCost.csv with the sqls to execute
# # the sqls are modified with pg_hint_plan hints to use the cardinalities output
# # by the given algorithm' estimates;
# python3 main.py --algs postgres -n 5 --query_template 1a --eval_fns qerr,ppc,plancost
#
# # executes the sqls on PostgreSQL server, with the given credientials
# python3 evaluation/get_runtimes.py --port 5432 --user ceb --pwd password --result_dir results/Postgres
# ```

# %% [markdown]
# ## Learned Model

# %%
import wandb
# log in wandb to upload/download weights & Biases
# https://wandb.ai/authorize
wandb.login()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: erostrate9 (ericsun). Use `wandb login --relogin` to force relogin
# True

# %%
# %%bash
# cd /content/Robust-MSCN
# bash scripts/download_imdb_workload.sh

# %% [markdown]
# ### Seen template

# %%
# !python3 main.py --config configs/config-seen-postgres.yaml --alg true --result_dir ./results/seen/true
# Out:
# device used in experiemnt: cpu
# flow loss C library not being used as we are not on linux
# data:
#   bitmap_dir: ./queries/allbitmaps/
#   diff_templates_seed: 1
#   eval_query_dir: ./queries/ceb-imdb
#   eval_templates: all
#   no_regex_templates: 0
#   num_samples_per_template: -1
#   only_pgplan_data: 0
#   query_dir: ./queries/ceb-imdb
#   query_templates: all
#   seed: 123
#   skip7a: 1
#   test_size: 0.4
#   test_tmps: null
#   train_test_split_kind: query
#   train_tmps: null
#   val_size: 0.2
# db:
#   db_host: localhost
#   db_name: imdb
#   port: 5432
#   pwd: password
#   user: imdb
# eval:
#   num_processes: 16
#   save_pdf_plans: 0
#   save_test_preds: 0
#   use_wandb: 0
# featurizer:
#   bitmap_onehotmask: 1
#   clamp_timeouts: 1
#   embedding_fn: null
#   embedding_pooling: null
#   feat_mcvs: 0
#   feat_onlyseen_maxy: 1
#   feat_onlyseen_preds: 1
#   feat_separate_alias: 0
#   feat_separate_like_ests: 0
#   global_feat_tables: 0
#   global_features: 1
#   heuristic_features: 1
#   implied_pred_features: 0
#   join_bitmap: 0
#   join_features: onehot
#   like_char_features: 0
#   max_discrete_featurizing_buckets: 1
#   max_like_featurizing_buckets: 1
#   pred_features: 1
#   sample_bitmap: 0
#   sample_bitmap_buckets: 1000
#   sample_bitmap_num: 1000
#   set_column_feature: onehot
#   table_features: 1
#   true_base_cards: 0
#   use_saved_feats: 0
#   ynormalization: log
# model:
#   clip_gradient: 20.0
#   comb_dropout: 0.0
#   cost_model: C
#   early_stopping: 0
#   eval_epoch: 1
#   eval_fns: qerr,ppc
#   heuristic_unseen_preds: null
#   hidden_layer_size: 128
#   hl_dropout: 0.0
#   inp_dropout: 0.0
#   load_padded_mscn_feats: 1
#   load_query_together: 0
#   loss_func_name: mse
#   lr: 0.0001
#   mask_unseen_subplans: 0
#   max_epochs: 1
#   max_num_tables: -1
#   mb_size: 1024
#   normalize_flow_loss: 1
#   num_hidden_layers: 2
#   onehot_dropout: 0
#   onehot_mask_truep: 0.8
#   onehot_reg: 0
#   onehot_reg_decay: 0.01
#   opt_lr: 0.005
#   optimizer_name: adamw
#   other_hid_units: null
#   random_bitmap_idx: 0
#   reg_loss: 0
#   subplan_level_outputs: 0
#   swa_start: 5
#   test_random_bitmap: 0
#   training_opt: ''
#   weight_decay: 0.0
#
# Skipped templates:  7a
# going to read only 509 CEB queries
# Selected Queries: 1441 train, 971 test, 595 val, 488 eval
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# /Users/erostrate9/Desktop/CSI5137F Data Management/project/project2/Robust-MSCN/evaluation/eval_fns.py:470: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined_df = pd.concat([costs_df, cur_df], ignore_index=True)
# train, True. All templates. #samples: 1441, Relative Postgres Cost: 1.0
# Template: 2a, #samples: 186 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 1a, #samples: 300 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 10a, #samples: 33 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 6a, #samples: 105 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 9a, #samples: 124 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 2c, #samples: 55 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 2b, #samples: 136 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 9b, #samples: 55 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 11b, #samples: 102 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 8a, #samples: 136 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 3a, #samples: 58 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 5a, #samples: 43 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 3b, #samples: 36 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 11a, #samples: 68 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 4a, #samples: 4 Relative Postgres Cost: 1.0, Avg Err: 0.0
# imdb, train, True, #samples: 1441, PostgresPlanCost-C: mean: 8034643.655, median: 806635.22, 99p: 246315014.706
# imdb, train, True, #samples: 467184, QError: mean: 1.0, median: 1.0, 99p: 1.0
# All loss computations took:  44.577999114990234
# true Evaluation time on train set: 44.58 seconds
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# val, True. All templates. #samples: 595, Relative Postgres Cost: 1.0
# Template: 1a, #samples: 124 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 8a, #samples: 56 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 9a, #samples: 52 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 2a, #samples: 77 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 9b, #samples: 23 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 3a, #samples: 24 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 2b, #samples: 56 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 6a, #samples: 44 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 11b, #samples: 42 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 10a, #samples: 13 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 5a, #samples: 17 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 3b, #samples: 15 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 11a, #samples: 28 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 2c, #samples: 23 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 4a, #samples: 1 Relative Postgres Cost: 1.0, Avg Err: 0.0
# imdb, val, True, #samples: 595, PostgresPlanCost-C: mean: 6591059.952, median: 899440.96, 99p: 167714712.828
# imdb, val, True, #samples: 193634, QError: mean: 1.0, median: 1.0, 99p: 1.0
# All loss computations took:  21.016170024871826
# true Evaluation time on val set: 21.02 seconds
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# test, True. All templates. #samples: 971, Relative Postgres Cost: 1.0
# Template: 1a, #samples: 200 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 6a, #samples: 71 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 2b, #samples: 92 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 9a, #samples: 84 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 2a, #samples: 125 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 3a, #samples: 39 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 8a, #samples: 92 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 10a, #samples: 22 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 11a, #samples: 46 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 9b, #samples: 38 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 11b, #samples: 68 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 5a, #samples: 29 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 2c, #samples: 37 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 3b, #samples: 24 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 4a, #samples: 4 Relative Postgres Cost: 1.0, Avg Err: 0.0
# imdb, test, True, #samples: 971, PostgresPlanCost-C: mean: 7310472.611, median: 846985.21, 99p: 252580116.972
# imdb, test, True, #samples: 314791, QError: mean: 1.0, median: 1.0, 99p: 1.0
# All loss computations took:  28.72379207611084
# true Evaluation time on test set: 28.73 seconds
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# ./queries/ceb-imdb, True. All templates. #samples: 488, Relative Postgres Cost: 1.0
# Template: 9a, #samples: 42 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 9b, #samples: 19 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 6a, #samples: 36 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 8a, #samples: 46 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 2b, #samples: 46 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 3a, #samples: 20 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 2a, #samples: 63 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 1a, #samples: 100 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 11b, #samples: 34 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 2c, #samples: 19 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 5a, #samples: 15 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 10a, #samples: 11 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 11a, #samples: 23 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 3b, #samples: 12 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 4a, #samples: 2 Relative Postgres Cost: 1.0, Avg Err: 0.0
# imdb, ./queries/ceb-imdb, True, #samples: 488, PostgresPlanCost-C: mean: 5115054.549, median: 856905.52, 99p: 59661542.592
# imdb, ./queries/ceb-imdb, True, #samples: 158525, QError: mean: 1.0, median: 1.0, 99p: 1.0
# All loss computations took:  17.271207809448242
# Evaluation time on eval set 0: 17.27 seconds

# %%
# !python3 main.py --config configs/config-seen-postgres.yaml --alg postgres --result_dir ./results/seen/postgres
# Out:
# device used in experiemnt: cpu
# flow loss C library not being used as we are not on linux
# data:
#   bitmap_dir: ./queries/allbitmaps/
#   diff_templates_seed: 1
#   eval_query_dir: ./queries/ceb-imdb
#   eval_templates: all
#   no_regex_templates: 0
#   num_samples_per_template: -1
#   only_pgplan_data: 0
#   query_dir: ./queries/ceb-imdb
#   query_templates: all
#   seed: 123
#   skip7a: 1
#   test_size: 0.4
#   test_tmps: null
#   train_test_split_kind: query
#   train_tmps: null
#   val_size: 0.2
# db:
#   db_host: localhost
#   db_name: imdb
#   port: 5432
#   pwd: password
#   user: imdb
# eval:
#   num_processes: 16
#   save_pdf_plans: 0
#   save_test_preds: 0
#   use_wandb: 0
# featurizer:
#   bitmap_onehotmask: 1
#   clamp_timeouts: 1
#   embedding_fn: null
#   embedding_pooling: null
#   feat_mcvs: 0
#   feat_onlyseen_maxy: 1
#   feat_onlyseen_preds: 1
#   feat_separate_alias: 0
#   feat_separate_like_ests: 0
#   global_feat_tables: 0
#   global_features: 1
#   heuristic_features: 1
#   implied_pred_features: 0
#   join_bitmap: 0
#   join_features: onehot
#   like_char_features: 0
#   max_discrete_featurizing_buckets: 1
#   max_like_featurizing_buckets: 1
#   pred_features: 1
#   sample_bitmap: 0
#   sample_bitmap_buckets: 1000
#   sample_bitmap_num: 1000
#   set_column_feature: onehot
#   table_features: 1
#   true_base_cards: 0
#   use_saved_feats: 0
#   ynormalization: log
# model:
#   clip_gradient: 20.0
#   comb_dropout: 0.0
#   cost_model: C
#   early_stopping: 0
#   eval_epoch: 1
#   eval_fns: qerr,ppc
#   heuristic_unseen_preds: null
#   hidden_layer_size: 128
#   hl_dropout: 0.0
#   inp_dropout: 0.0
#   load_padded_mscn_feats: 1
#   load_query_together: 0
#   loss_func_name: mse
#   lr: 0.0001
#   mask_unseen_subplans: 0
#   max_epochs: 1
#   max_num_tables: -1
#   mb_size: 1024
#   normalize_flow_loss: 1
#   num_hidden_layers: 2
#   onehot_dropout: 0
#   onehot_mask_truep: 0.8
#   onehot_reg: 0
#   onehot_reg_decay: 0.01
#   opt_lr: 0.005
#   optimizer_name: adamw
#   other_hid_units: null
#   random_bitmap_idx: 0
#   reg_loss: 0
#   subplan_level_outputs: 0
#   swa_start: 5
#   test_random_bitmap: 0
#   training_opt: ''
#   weight_decay: 0.0
#
# Skipped templates:  7a
# going to read only 509 CEB queries
# Selected Queries: 1441 train, 971 test, 595 val, 488 eval
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# train, Postgres. All templates. #samples: 1441, Relative Postgres Cost: 2.242
# Template: 6a, #samples: 105 Relative Postgres Cost: 54.531, Avg Err: 22111044.706
# Template: 9b, #samples: 55 Relative Postgres Cost: 2.622, Avg Err: 1372885.505
# Template: 2c, #samples: 55 Relative Postgres Cost: 1.088, Avg Err: 20808.823
# Template: 1a, #samples: 300 Relative Postgres Cost: 5.39, Avg Err: 5045561.13
# Template: 11b, #samples: 102 Relative Postgres Cost: 3.919, Avg Err: 25988930.929
# Template: 2b, #samples: 136 Relative Postgres Cost: 8.571, Avg Err: 4439110.279
# Template: 8a, #samples: 136 Relative Postgres Cost: 11.305, Avg Err: 9160639.232
# Template: 3b, #samples: 36 Relative Postgres Cost: 1.212, Avg Err: 48328.335
# Template: 2a, #samples: 186 Relative Postgres Cost: 7.468, Avg Err: 6793192.14
# Template: 11a, #samples: 68 Relative Postgres Cost: 1.31, Avg Err: 2234658.492
# Template: 9a, #samples: 124 Relative Postgres Cost: 1.511, Avg Err: 35133897.137
# Template: 3a, #samples: 58 Relative Postgres Cost: 3.22, Avg Err: 184537.079
# Template: 10a, #samples: 33 Relative Postgres Cost: 1.171, Avg Err: 3123215.325
# Template: 4a, #samples: 4 Relative Postgres Cost: 1.188, Avg Err: 525161.46
# Template: 5a, #samples: 43 Relative Postgres Cost: 1.421, Avg Err: 1860825.876
# imdb, train, Postgres, #samples: 1441, PostgresPlanCost-C: mean: 18015307.85, median: 2393635.07, 99p: 336084643.912
# imdb, train, Postgres, #samples: 467184, QError: mean: 93799.827, median: 33.252, 99p: 1447506.915
# All loss computations took:  39.77139592170715
# postgres Evaluation time on train set: 39.78 seconds
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# val, Postgres. All templates. #samples: 595, Relative Postgres Cost: 2.904
# Template: 9a, #samples: 52 Relative Postgres Cost: 1.324, Avg Err: 18376667.477
# Template: 8a, #samples: 56 Relative Postgres Cost: 10.568, Avg Err: 8725919.523
# Template: 11b, #samples: 42 Relative Postgres Cost: 5.937, Avg Err: 45407817.888
# Template: 10a, #samples: 13 Relative Postgres Cost: 2.774, Avg Err: 1685825.121
# Template: 11a, #samples: 28 Relative Postgres Cost: 29.163, Avg Err: 41271446.669
# Template: 2b, #samples: 56 Relative Postgres Cost: 7.945, Avg Err: 4964671.45
# Template: 9b, #samples: 23 Relative Postgres Cost: 1.261, Avg Err: 2028532.871
# Template: 1a, #samples: 124 Relative Postgres Cost: 4.896, Avg Err: 4606866.6
# Template: 2c, #samples: 23 Relative Postgres Cost: 1.104, Avg Err: 26846.807
# Template: 2a, #samples: 77 Relative Postgres Cost: 8.22, Avg Err: 7973897.897
# Template: 6a, #samples: 44 Relative Postgres Cost: 73.072, Avg Err: 31257189.586
# Template: 5a, #samples: 17 Relative Postgres Cost: 19.674, Avg Err: 2524963.205
# Template: 3b, #samples: 15 Relative Postgres Cost: 1.219, Avg Err: 39029.604
# Template: 3a, #samples: 24 Relative Postgres Cost: 3.877, Avg Err: 303544.121
# Template: 4a, #samples: 1 Relative Postgres Cost: 1.0, Avg Err: 0.0
# imdb, val, Postgres, #samples: 595, PostgresPlanCost-C: mean: 19138170.77, median: 2855277.08, 99p: 334483394.223
# imdb, val, Postgres, #samples: 193634, QError: mean: 91988.463, median: 31.0, 99p: 1532898.37
# All loss computations took:  20.75898003578186
# postgres Evaluation time on val set: 20.76 seconds
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# test, Postgres. All templates. #samples: 971, Relative Postgres Cost: 2.205
# Template: 2a, #samples: 125 Relative Postgres Cost: 11.473, Avg Err: 10572092.708
# Template: 6a, #samples: 71 Relative Postgres Cost: 55.876, Avg Err: 18630840.022
# Template: 3a, #samples: 39 Relative Postgres Cost: 4.091, Avg Err: 296573.204
# Template: 1a, #samples: 200 Relative Postgres Cost: 5.367, Avg Err: 5295189.299
# Template: 9b, #samples: 38 Relative Postgres Cost: 3.974, Avg Err: 2629895.095
# Template: 8a, #samples: 92 Relative Postgres Cost: 9.858, Avg Err: 7465909.686
# Template: 9a, #samples: 84 Relative Postgres Cost: 1.313, Avg Err: 18443174.174
# Template: 4a, #samples: 4 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 2c, #samples: 37 Relative Postgres Cost: 1.077, Avg Err: 19321.849
# Template: 5a, #samples: 29 Relative Postgres Cost: 6.411, Avg Err: 1836370.529
# Template: 2b, #samples: 92 Relative Postgres Cost: 12.62, Avg Err: 6233531.965
# Template: 3b, #samples: 24 Relative Postgres Cost: 1.5, Avg Err: 105847.87
# Template: 11a, #samples: 46 Relative Postgres Cost: 2.488, Avg Err: 7467164.341
# Template: 10a, #samples: 22 Relative Postgres Cost: 2.935, Avg Err: 2031041.028
# Template: 11b, #samples: 68 Relative Postgres Cost: 2.131, Avg Err: 21817327.326
# imdb, test, Postgres, #samples: 971, PostgresPlanCost-C: mean: 16118585.324, median: 2290590.79, 99p: 309508758.633
# imdb, test, Postgres, #samples: 314791, QError: mean: 79803.96, median: 31.15, 99p: 1300081.5
# All loss computations took:  30.9172580242157
# postgres Evaluation time on test set: 30.92 seconds
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# device used in experiemnt: cpu
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# flow loss C library not being used as we are not on linux
# ./queries/ceb-imdb, Postgres. All templates. #samples: 488, Relative Postgres Cost: 2.77
# Template: 8a, #samples: 46 Relative Postgres Cost: 12.072, Avg Err: 10008269.619
# Template: 11b, #samples: 34 Relative Postgres Cost: 5.89, Avg Err: 28263294.235
# Template: 3b, #samples: 12 Relative Postgres Cost: 1.238, Avg Err: 64997.754
# Template: 2a, #samples: 63 Relative Postgres Cost: 5.852, Avg Err: 4621487.798
# Template: 1a, #samples: 100 Relative Postgres Cost: 5.735, Avg Err: 5719254.053
# Template: 2c, #samples: 19 Relative Postgres Cost: 1.059, Avg Err: 14403.547
# Template: 3a, #samples: 20 Relative Postgres Cost: 6.128, Avg Err: 415833.685
# Template: 9a, #samples: 42 Relative Postgres Cost: 1.53, Avg Err: 24811889.815
# Template: 2b, #samples: 46 Relative Postgres Cost: 7.182, Avg Err: 3130319.002
# Template: 10a, #samples: 11 Relative Postgres Cost: 2.38, Avg Err: 1403853.158
# Template: 6a, #samples: 36 Relative Postgres Cost: 47.794, Avg Err: 16358456.185
# Template: 11a, #samples: 23 Relative Postgres Cost: 12.173, Avg Err: 11136645.437
# Template: 4a, #samples: 2 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 9b, #samples: 19 Relative Postgres Cost: 3.905, Avg Err: 2443216.911
# Template: 5a, #samples: 15 Relative Postgres Cost: 4.56, Avg Err: 2063668.427
# imdb, ./queries/ceb-imdb, Postgres, #samples: 488, PostgresPlanCost-C: mean: 14167803.941, median: 2251573.73, 99p: 260527806.113
# imdb, ./queries/ceb-imdb, Postgres, #samples: 158525, QError: mean: 75317.044, median: 28.194, 99p: 1172352.56
# All loss computations took:  16.624006986618042
# Evaluation time on eval set 0: 16.63 seconds

# %%
# !python3 main.py --config configs/config-seen-mse.yaml --alg mscn --result_dir ./results

# %%
# !python3 main.py --config configs/config-seen-mse.yaml --alg mscn --result_dir ./results/seen/mscn/mse
# Out:
# data:
#   bitmap_dir: ./queries/allbitmaps/
#   diff_templates_seed: 1
#   eval_query_dir: ./queries/ceb-imdb
#   eval_templates: all
#   no_regex_templates: 0
#   num_samples_per_template: -1
#   only_pgplan_data: 0
#   query_dir: ./queries/ceb-imdb
#   query_templates: all
#   seed: 123
#   skip7a: 1
#   test_size: 0.4
#   test_tmps: null
#   train_test_split_kind: query
#   train_tmps: null
#   val_size: 0.2
# db:
#   db_host: localhost
#   db_name: imdb
#   port: 5432
#   pwd: password
#   user: imdb
# eval:
#   num_processes: -1
#   save_pdf_plans: 0
#   save_test_preds: 0
#   use_wandb: 0
# featurizer:
#   bitmap_onehotmask: 1
#   clamp_timeouts: 1
#   embedding_fn: null
#   embedding_pooling: null
#   feat_mcvs: 0
#   feat_onlyseen_maxy: 1
#   feat_onlyseen_preds: 1
#   feat_separate_alias: 0
#   feat_separate_like_ests: 0
#   global_feat_tables: 0
#   global_features: 1
#   heuristic_features: 1
#   implied_pred_features: 0
#   join_bitmap: 0
#   join_features: onehot
#   like_char_features: 0
#   max_discrete_featurizing_buckets: 1
#   max_like_featurizing_buckets: 1
#   pred_features: 1
#   sample_bitmap: 0
#   sample_bitmap_buckets: 1000
#   sample_bitmap_num: 1000
#   set_column_feature: onehot
#   table_features: 1
#   true_base_cards: 0
#   use_saved_feats: 0
#   ynormalization: log
# model:
#   clip_gradient: 20.0
#   comb_dropout: 0.0
#   cost_model: C
#   early_stopping: 0
#   eval_epoch: 2
#   eval_fns: qerr,ppc
#   heuristic_unseen_preds: null
#   hidden_layer_size: 128
#   hl_dropout: 0.0
#   inp_dropout: 0.0
#   load_padded_mscn_feats: 1
#   load_query_together: 0
#   loss_func_name: mse
#   lr: 0.0001
#   mask_unseen_subplans: 0
#   max_epochs: 10
#   max_num_tables: -1
#   mb_size: 1024
#   normalize_flow_loss: 1
#   num_hidden_layers: 2
#   onehot_dropout: 0
#   onehot_mask_truep: 0.8
#   onehot_reg: 0
#   onehot_reg_decay: 0.01
#   opt_lr: 0.005
#   optimizer_name: adamw
#   other_hid_units: null
#   random_bitmap_idx: 0
#   reg_loss: 0
#   subplan_level_outputs: 0
#   swa_start: 5
#   test_random_bitmap: 0
#   training_opt: ''
#   weight_decay: 0.0
#
# Skipped templates:  7a
# going to read only 509 CEB queries
# Selected Queries: 1441 train, 971 test, 595 val, 488 eval
# Updated stats to remove alias based columns
# Max tables: 14 , Max pred vals: 56 ,Max joins: 18
# max pred vals: 56
# Seen comparison operators:  {'like', 'in', 'lt', 'eq'}
# Tables:  {'movie_info', 'person_info', 'cast_info', 'movie_keyword', 'info_type', 'movie_info_idx', 'role_type', 'keyword', 'company_type', 'movie_companies', 'kind_type', 'name', 'title', 'aka_name', 'company_name'}
# Number of global features:  1
# min y: 0.0, max y: 24.44008533063267
# Features not saved before.
# Extracting features took:  108.37480998039246
# Features not saved before.
# Extracting features took:  48.4106559753418
# Features not saved before.
# Extracting features took:  6.312989950180054
# Features not saved before.
# Extracting features took:  6.368600845336914
# Features not saved before.
# Extracting features took:  29.252756118774414
# Traceback (most recent call last):
#   File "/Users/erostrate9/Desktop/CSI5137F Data Management/project/project2/Robust-MSCN/main.py", line 284, in <module>
#     main()
#   File "/Users/erostrate9/Desktop/CSI5137F Data Management/project/project2/Robust-MSCN/main.py", line 226, in main
#     alg.train(trainqs, valqs=valqs, testqs=testqs, evalqs = evalqs,
#   File "/Users/erostrate9/Desktop/CSI5137F Data Management/project/project2/Robust-MSCN/cardinality_estimation/algs.py", line 589, in train
#     self.net, self.optimizer = self.init_net(self.trainds[0])
#   File "/Users/erostrate9/Desktop/CSI5137F Data Management/project/project2/Robust-MSCN/cardinality_estimation/algs.py", line 271, in init_net
#     net = self._init_net(sample)
#   File "/Users/erostrate9/Desktop/CSI5137F Data Management/project/project2/Robust-MSCN/cardinality_estimation/mscn.py", line 69, in _init_net
#     net = SetConv(sfeats,
#   File "/Users/erostrate9/Desktop/CSI5137F Data Management/project/project2/Robust-MSCN/cardinality_estimation/nets.py", line 113, in __init__
#     sample_mlp1 = nn.Linear(sample_feats, sample_hid_units).to(device)
# NameError: name 'device' is not defined

# %%
# !python3 main.py --config configs/config-seen-flowloss.yaml --alg mscn --result_dir ./results/seen/mscn/flowloss

# %% [markdown]
# ### Unseen template

# %%
# !python3 main.py --config configs/config-unseen-postgres.yaml --alg true --result_dir ./results/unseen/true
# Out:
# data:
#   bitmap_dir: ./queries/allbitmaps/
#   diff_templates_seed: 1
#   eval_query_dir: ./queries/ceb-imdb
#   eval_templates: all
#   no_regex_templates: 0
#   num_samples_per_template: -1
#   only_pgplan_data: 0
#   query_dir: ./queries/ceb-imdb
#   query_templates: all
#   seed: 123
#   skip7a: 1
#   test_size: 0.4
#   test_tmps: null
#   train_test_split_kind: template
#   train_tmps: null
#   val_size: 0.2
# db:
#   db_host: localhost
#   db_name: imdb
#   port: 5432
#   pwd: password
#   user: imdb
# eval:
#   num_processes: 16
#   save_pdf_plans: 0
#   save_test_preds: 0
#   use_wandb: 0
# featurizer:
#   bitmap_onehotmask: 1
#   clamp_timeouts: 1
#   embedding_fn: null
#   embedding_pooling: null
#   feat_mcvs: 0
#   feat_onlyseen_maxy: 1
#   feat_onlyseen_preds: 1
#   feat_separate_alias: 0
#   feat_separate_like_ests: 0
#   global_feat_tables: 0
#   global_features: 1
#   heuristic_features: 1
#   implied_pred_features: 0
#   join_bitmap: 0
#   join_features: onehot
#   like_char_features: 0
#   max_discrete_featurizing_buckets: 1
#   max_like_featurizing_buckets: 1
#   pred_features: 1
#   sample_bitmap: 0
#   sample_bitmap_buckets: 1000
#   sample_bitmap_num: 1000
#   set_column_feature: onehot
#   table_features: 1
#   true_base_cards: 0
#   use_saved_feats: 0
#   ynormalization: log
# model:
#   clip_gradient: 20.0
#   comb_dropout: 0.0
#   cost_model: C
#   early_stopping: 0
#   eval_epoch: 1
#   eval_fns: qerr,ppc
#   heuristic_unseen_preds: null
#   hidden_layer_size: 128
#   hl_dropout: 0.0
#   inp_dropout: 0.0
#   load_padded_mscn_feats: 1
#   load_query_together: 0
#   loss_func_name: mse
#   lr: 0.0001
#   mask_unseen_subplans: 0
#   max_epochs: 1
#   max_num_tables: -1
#   mb_size: 1024
#   normalize_flow_loss: 1
#   num_hidden_layers: 2
#   onehot_dropout: 0
#   onehot_mask_truep: 0.8
#   onehot_reg: 0
#   onehot_reg_decay: 0.01
#   opt_lr: 0.005
#   optimizer_name: adamw
#   other_hid_units: null
#   random_bitmap_idx: 0
#   reg_loss: 0
#   subplan_level_outputs: 0
#   swa_start: 5
#   test_random_bitmap: 0
#   training_opt: ''
#   weight_decay: 0.0
#
# Skipped templates:  7a
# going to read only 509 CEB queries
# Selected 9 train templates, 7 test templates
# Training templates: 11a,9a,10a,9b,4a,3b,7a,6a,2b
# Evaluation templates: 1a,8a,3a,11b,2c,5a,2a
# Selected Queries: 942 train, 1833 test, 232 val, 488 eval
# train, True. All templates. #samples: 942, Relative Postgres Cost: 1.0
# Template: 2b, #samples: 228 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 4a, #samples: 8 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 9a, #samples: 208 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 11a, #samples: 114 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 6a, #samples: 176 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 3b, #samples: 60 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 9b, #samples: 93 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 10a, #samples: 55 Relative Postgres Cost: 1.0, Avg Err: 0.0
# imdb, train, True, #samples: 942, PostgresPlanCost-C: mean: 16575214.674, median: 637117.24, 99p: 378438558.07
# imdb, train, True, #samples: 383641, QError: mean: 1.0, median: 1.0, 99p: 1.0
# All loss computations took:  49.54057598114014
# true Evaluation time on train set: 49.55 seconds
# val, True. All templates. #samples: 232, Relative Postgres Cost: 1.0
# Template: 9b, #samples: 23 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 9a, #samples: 52 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 6a, #samples: 44 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 10a, #samples: 13 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 2b, #samples: 56 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 11a, #samples: 28 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 3b, #samples: 15 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 4a, #samples: 1 Relative Postgres Cost: 1.0, Avg Err: 0.0
# imdb, val, True, #samples: 232, PostgresPlanCost-C: mean: 11837104.005, median: 639940.15, 99p: 350326816.993
# imdb, val, True, #samples: 95414, QError: mean: 1.0, median: 1.0, 99p: 1.0
# All loss computations took:  17.444605827331543
# true Evaluation time on val set: 17.45 seconds
# test, True. All templates. #samples: 1833, Relative Postgres Cost: 1.0
# Template: 8a, #samples: 284 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 1a, #samples: 624 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 2a, #samples: 388 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 3a, #samples: 121 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 2c, #samples: 115 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 11b, #samples: 212 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 5a, #samples: 89 Relative Postgres Cost: 1.0, Avg Err: 0.0
# imdb, test, True, #samples: 1833, PostgresPlanCost-C: mean: 2312062.592, median: 957481.11, 99p: 28418995.314
# imdb, test, True, #samples: 496554, QError: mean: 1.0, median: 1.0, 99p: 1.0
# All loss computations took:  26.068381786346436
# true Evaluation time on test set: 26.07 seconds
# ./queries/ceb-imdb, True. All templates. #samples: 488, Relative Postgres Cost: 1.0
# Template: 5a, #samples: 15 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 3a, #samples: 20 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 2b, #samples: 46 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 1a, #samples: 100 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 9b, #samples: 19 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 11b, #samples: 34 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 8a, #samples: 46 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 6a, #samples: 36 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 2a, #samples: 63 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 9a, #samples: 42 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 3b, #samples: 12 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 4a, #samples: 2 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 2c, #samples: 19 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 11a, #samples: 23 Relative Postgres Cost: 1.0, Avg Err: 0.0
# Template: 10a, #samples: 11 Relative Postgres Cost: 1.0, Avg Err: 0.0
# imdb, ./queries/ceb-imdb, True, #samples: 488, PostgresPlanCost-C: mean: 5115054.549, median: 856905.52, 99p: 59661542.592
# imdb, ./queries/ceb-imdb, True, #samples: 158525, QError: mean: 1.0, median: 1.0, 99p: 1.0
# All loss computations took:  16.878301858901978
# Evaluation time on eval set 0: 16.88 seconds

# %%
# !python3 main.py --config configs/config-unseen-postgres.yaml --alg postgres --result_dir ./results/unseen/postgres
# Out:
# data:
#   bitmap_dir: ./queries/allbitmaps/
#   diff_templates_seed: 1
#   eval_query_dir: ./queries/ceb-imdb
#   eval_templates: all
#   no_regex_templates: 0
#   num_samples_per_template: -1
#   only_pgplan_data: 0
#   query_dir: ./queries/ceb-imdb
#   query_templates: all
#   seed: 123
#   skip7a: 1
#   test_size: 0.4
#   test_tmps: null
#   train_test_split_kind: template
#   train_tmps: null
#   val_size: 0.2
# db:
#   db_host: localhost
#   db_name: imdb
#   port: 5432
#   pwd: password
#   user: imdb
# eval:
#   num_processes: 16
#   save_pdf_plans: 0
#   save_test_preds: 0
#   use_wandb: 0
# featurizer:
#   bitmap_onehotmask: 1
#   clamp_timeouts: 1
#   embedding_fn: null
#   embedding_pooling: null
#   feat_mcvs: 0
#   feat_onlyseen_maxy: 1
#   feat_onlyseen_preds: 1
#   feat_separate_alias: 0
#   feat_separate_like_ests: 0
#   global_feat_tables: 0
#   global_features: 1
#   heuristic_features: 1
#   implied_pred_features: 0
#   join_bitmap: 0
#   join_features: onehot
#   like_char_features: 0
#   max_discrete_featurizing_buckets: 1
#   max_like_featurizing_buckets: 1
#   pred_features: 1
#   sample_bitmap: 0
#   sample_bitmap_buckets: 1000
#   sample_bitmap_num: 1000
#   set_column_feature: onehot
#   table_features: 1
#   true_base_cards: 0
#   use_saved_feats: 0
#   ynormalization: log
# model:
#   clip_gradient: 20.0
#   comb_dropout: 0.0
#   cost_model: C
#   early_stopping: 0
#   eval_epoch: 1
#   eval_fns: qerr,ppc
#   heuristic_unseen_preds: null
#   hidden_layer_size: 128
#   hl_dropout: 0.0
#   inp_dropout: 0.0
#   load_padded_mscn_feats: 1
#   load_query_together: 0
#   loss_func_name: mse
#   lr: 0.0001
#   mask_unseen_subplans: 0
#   max_epochs: 1
#   max_num_tables: -1
#   mb_size: 1024
#   normalize_flow_loss: 1
#   num_hidden_layers: 2
#   onehot_dropout: 0
#   onehot_mask_truep: 0.8
#   onehot_reg: 0
#   onehot_reg_decay: 0.01
#   opt_lr: 0.005
#   optimizer_name: adamw
#   other_hid_units: null
#   random_bitmap_idx: 0
#   reg_loss: 0
#   subplan_level_outputs: 0
#   swa_start: 5
#   test_random_bitmap: 0
#   training_opt: ''
#   weight_decay: 0.0
#
# Skipped templates:  7a
# going to read only 509 CEB queries
# Selected 9 train templates, 7 test templates
# Training templates: 11a,9a,10a,9b,4a,3b,7a,6a,2b
# Evaluation templates: 1a,8a,3a,11b,2c,5a,2a
# Selected Queries: 942 train, 1833 test, 232 val, 488 eval
# /Users/erostrate9/Desktop/CSI5137F Data Management/project/project2/Robust-MSCN/evaluation/eval_fns.py:470: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined_df = pd.concat([costs_df, cur_df], ignore_index=True)
# train, Postgres. All templates. #samples: 942, Relative Postgres Cost: 1.725
# Template: 2b, #samples: 228 Relative Postgres Cost: 10.29, Avg Err: 5399947.057
# Template: 10a, #samples: 55 Relative Postgres Cost: 3.765, Avg Err: 2760897.245
# Template: 9a, #samples: 208 Relative Postgres Cost: 1.283, Avg Err: 19549366.622
# Template: 11a, #samples: 114 Relative Postgres Cost: 3.126, Avg Err: 13596215.737
# Template: 3b, #samples: 60 Relative Postgres Cost: 1.341, Avg Err: 69539.587
# Template: 9b, #samples: 93 Relative Postgres Cost: 1.822, Avg Err: 2121487.849
# Template: 6a, #samples: 176 Relative Postgres Cost: 60.635, Avg Err: 23389188.993
# Template: 4a, #samples: 8 Relative Postgres Cost: 1.118, Avg Err: 262580.73
# imdb, train, Postgres, #samples: 942, PostgresPlanCost-C: mean: 28591502.13, median: 2353115.755, 99p: 499338558.265
# imdb, train, Postgres, #samples: 383641, QError: mean: 119156.252, median: 354.5, 99p: 2064898.0
# All loss computations took:  47.63140821456909
# postgres Evaluation time on train set: 47.64 seconds
# val, Postgres. All templates. #samples: 232, Relative Postgres Cost: 2.481
# Template: 9a, #samples: 52 Relative Postgres Cost: 2.361, Avg Err: 53752852.44
# Template: 10a, #samples: 13 Relative Postgres Cost: 1.031, Avg Err: 1370414.338
# Template: 6a, #samples: 44 Relative Postgres Cost: 52.527, Avg Err: 20528827.605
# Template: 3b, #samples: 15 Relative Postgres Cost: 1.185, Avg Err: 46215.854
# Template: 9b, #samples: 23 Relative Postgres Cost: 2.322, Avg Err: 1078374.019
# Template: 2b, #samples: 56 Relative Postgres Cost: 7.122, Avg Err: 4000671.624
# Template: 11a, #samples: 28 Relative Postgres Cost: 4.062, Avg Err: 3609937.492
# Template: 4a, #samples: 1 Relative Postgres Cost: 1.0, Avg Err: 0.0
# imdb, val, Postgres, #samples: 232, PostgresPlanCost-C: mean: 29366603.267, median: 2489768.285, 99p: 448329532.15
# imdb, val, Postgres, #samples: 95414, QError: mean: 131847.338, median: 417.109, 99p: 2217387.78
# All loss computations took:  15.000823974609375
# postgres Evaluation time on val set: 15.00 seconds
# test, Postgres. All templates. #samples: 1833, Relative Postgres Cost: 4.543
# Template: 11b, #samples: 212 Relative Postgres Cost: 3.318, Avg Err: 28498007.378
# Template: 8a, #samples: 284 Relative Postgres Cost: 10.704, Avg Err: 8525922.958
# Template: 1a, #samples: 624 Relative Postgres Cost: 5.284, Avg Err: 5038393.681
# Template: 3a, #samples: 121 Relative Postgres Cost: 3.664, Avg Err: 244252.599
# Template: 5a, #samples: 89 Relative Postgres Cost: 1.872, Avg Err: 1979714.972
# Template: 2a, #samples: 388 Relative Postgres Cost: 8.868, Avg Err: 8244936.765
# Template: 2c, #samples: 115 Relative Postgres Cost: 1.088, Avg Err: 21538.002
# imdb, test, Postgres, #samples: 1833, PostgresPlanCost-C: mean: 10503093.074, median: 2463092.88, 99p: 130112846.725
# imdb, test, Postgres, #samples: 496554, QError: mean: 57319.316, median: 8.971, 99p: 679277.91
# All loss computations took:  25.689532995224
# postgres Evaluation time on test set: 25.70 seconds
# ./queries/ceb-imdb, Postgres. All templates. #samples: 488, Relative Postgres Cost: 2.77
# Template: 8a, #samples: 46 Relative Postgres Cost: 12.072, Avg Err: 10008269.619
# Template: 6a, #samples: 36 Relative Postgres Cost: 47.794, Avg Err: 16358456.185
# Template: 3a, #samples: 20 Relative Postgres Cost: 6.128, Avg Err: 415833.685
# Template: 5a, #samples: 15 Relative Postgres Cost: 4.56, Avg Err: 2063668.427
# Template: 9b, #samples: 19 Relative Postgres Cost: 3.905, Avg Err: 2443216.911
# Template: 1a, #samples: 100 Relative Postgres Cost: 5.735, Avg Err: 5719254.053
# Template: 11a, #samples: 23 Relative Postgres Cost: 12.173, Avg Err: 11136645.437
# Template: 9a, #samples: 42 Relative Postgres Cost: 1.53, Avg Err: 24811889.815
# Template: 2a, #samples: 63 Relative Postgres Cost: 5.852, Avg Err: 4621487.798
# Template: 11b, #samples: 34 Relative Postgres Cost: 5.89, Avg Err: 28263294.235
# Template: 2c, #samples: 19 Relative Postgres Cost: 1.059, Avg Err: 14403.547
# Template: 3b, #samples: 12 Relative Postgres Cost: 1.238, Avg Err: 64997.754
# Template: 2b, #samples: 46 Relative Postgres Cost: 7.182, Avg Err: 3130319.002
# Template: 10a, #samples: 11 Relative Postgres Cost: 2.38, Avg Err: 1403853.158
# Template: 4a, #samples: 2 Relative Postgres Cost: 1.0, Avg Err: 0.0
# imdb, ./queries/ceb-imdb, Postgres, #samples: 488, PostgresPlanCost-C: mean: 14167803.941, median: 2251573.73, 99p: 260527806.113
# imdb, ./queries/ceb-imdb, Postgres, #samples: 158525, QError: mean: 75317.044, median: 28.194, 99p: 1172352.56
# All loss computations took:  18.888068914413452
# Evaluation time on eval set 0: 18.89 seconds

# %%
# !python3 main.py --config configs/config-unseen-flowloss.yaml --alg mscn --result_dir ./results/unseen/mscn/mse
# Out:
# data:
#   bitmap_dir: ./queries/allbitmaps/
#   diff_templates_seed: 1
#   eval_query_dir: ./queries/ceb-imdb
#   eval_templates: all
#   no_regex_templates: 0
#   num_samples_per_template: -1
#   only_pgplan_data: 0
#   query_dir: ./queries/ceb-imdb
#   query_templates: all
#   seed: 123
#   skip7a: 1
#   test_size: 0.4
#   test_tmps: null
#   train_test_split_kind: template
#   train_tmps: null
#   val_size: 0.2
# db:
#   db_host: localhost
#   db_name: imdb
#   port: 5432
#   pwd: password
#   user: imdb
# eval:
#   num_processes: -1
#   save_pdf_plans: 0
#   save_test_preds: 0
#   use_wandb: 0
# featurizer:
#   bitmap_onehotmask: 1
#   clamp_timeouts: 1
#   embedding_fn: null
#   embedding_pooling: null
#   feat_mcvs: 0
#   feat_onlyseen_maxy: 1
#   feat_onlyseen_preds: 1
#   feat_separate_alias: 0
#   feat_separate_like_ests: 0
#   global_feat_tables: 0
#   global_features: 1
#   heuristic_features: 1
#   implied_pred_features: 0
#   join_bitmap: 0
#   join_features: onehot
#   like_char_features: 0
#   max_discrete_featurizing_buckets: 1
#   max_like_featurizing_buckets: 1
#   pred_features: 1
#   sample_bitmap: 0
#   sample_bitmap_buckets: 1000
#   sample_bitmap_num: 1000
#   set_column_feature: onehot
#   table_features: 1
#   true_base_cards: 0
#   use_saved_feats: 0
#   ynormalization: log
# model:
#   clip_gradient: 20.0
#   comb_dropout: 0.0
#   cost_model: C
#   early_stopping: 0
#   eval_epoch: 2
#   eval_fns: qerr,ppc
#   heuristic_unseen_preds: null
#   hidden_layer_size: 128
#   hl_dropout: 0.0
#   inp_dropout: 0.0
#   load_padded_mscn_feats: 1
#   load_query_together: 0
#   loss_func_name: flowloss
#   lr: 0.0001
#   mask_unseen_subplans: 0
#   max_epochs: 10
#   max_num_tables: -1
#   mb_size: 1024
#   normalize_flow_loss: 1
#   num_hidden_layers: 2
#   onehot_dropout: 0
#   onehot_mask_truep: 0.8
#   onehot_reg: 0
#   onehot_reg_decay: 0.01
#   opt_lr: 0.005
#   optimizer_name: adamw
#   other_hid_units: null
#   random_bitmap_idx: 0
#   reg_loss: 0
#   subplan_level_outputs: 0
#   swa_start: 5
#   test_random_bitmap: 0
#   training_opt: ''
#   weight_decay: 0.0
#
# Skipped templates:  7a
# going to read only 509 CEB queries
# Selected 9 train templates, 7 test templates
# Training templates: 11a,9a,10a,9b,4a,3b,7a,6a,2b
# Evaluation templates: 1a,8a,3a,11b,2c,5a,2a
# Selected Queries: 942 train, 1833 test, 232 val, 488 eval
# Updated stats to remove alias based columns
# updating global features to include flowloss specific ones
# Max tables: 14 , Max pred vals: 56 ,Max joins: 18
# max pred vals: 56
# Seen comparison operators:  {'eq', 'like', 'in', 'lt'}
# Tables:  {'movie_info_idx', 'aka_name', 'cast_info', 'info_type', 'company_name', 'role_type', 'title', 'keyword', 'movie_keyword', 'kind_type', 'movie_info', 'name', 'person_info', 'movie_companies', 'company_type'}
# Number of global features:  260
# min y: 0.0, max y: 22.286933710956678
# Features not saved before.
# Extracting features took:  96.12136101722717
# Features not saved before.
# Extracting features took:  22.77231001853943
# Features not saved before.
# Extracting features took:  15.619702100753784
# Features not saved before.
# Extracting features took:  6.969370126724243
# Features not saved before.
# Extracting features took:  28.144899129867554
# Traceback (most recent call last):
#   File "/Users/erostrate9/Desktop/CSI5137F Data Management/project/project2/Robust-MSCN/main.py", line 284, in <module>
#     main()
#   File "/Users/erostrate9/Desktop/CSI5137F Data Management/project/project2/Robust-MSCN/main.py", line 226, in main
#     alg.train(trainqs, valqs=valqs, testqs=testqs, evalqs = evalqs,
#   File "/Users/erostrate9/Desktop/CSI5137F Data Management/project/project2/Robust-MSCN/cardinality_estimation/algs.py", line 589, in train
#     self.net, self.optimizer = self.init_net(self.trainds[0])
#   File "/Users/erostrate9/Desktop/CSI5137F Data Management/project/project2/Robust-MSCN/cardinality_estimation/algs.py", line 271, in init_net
#     net = self._init_net(sample)
#   File "/Users/erostrate9/Desktop/CSI5137F Data Management/project/project2/Robust-MSCN/cardinality_estimation/mscn.py", line 59, in _init_net
#     net = SetConvFlow(sfeats,
#   File "/Users/erostrate9/Desktop/CSI5137F Data Management/project/project2/Robust-MSCN/cardinality_estimation/nets.py", line 306, in __init__
#     self.sample_mlp1 = nn.Linear(sample_feats, hid_units).to(device)
# NameError: name 'device' is not defined

# %%
# !python3 main.py --config configs/config-unseen-flowloss.yaml --alg mscn --result_dir ./results/unseen/mscn/flowloss
